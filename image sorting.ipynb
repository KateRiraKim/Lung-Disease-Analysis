# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

import os
import shutil
from PIL import Image

# %%
# load csv file for getting image index
df = pd.read_csv('../MLproject1_1/Data_Entry_2017.csv')
df.head(10)
# Out:
#         Image Index          Finding Labels  Follow-up #  Patient ID  \
# 0  00000001_000.png            Cardiomegaly            0           1
# 1  00000001_001.png  Cardiomegaly|Emphysema            1           1
# 2  00000001_002.png   Cardiomegaly|Effusion            2           1
# 3  00000002_000.png              No Finding            0           2
# 4  00000003_000.png                  Hernia            0           3
# 5  00000003_001.png                  Hernia            1           3
# 6  00000003_002.png                  Hernia            2           3
# 7  00000003_003.png     Hernia|Infiltration            3           3
# 8  00000003_004.png                  Hernia            4           3
# 9  00000003_005.png                  Hernia            5           3
#
#    Patient Age Patient Gender View Position  OriginalImage[Width  Height]  \
# 0           58              M            PA                 2682     2749
# ...

# %% [markdown]
# # make files for each main disease name.

# %%
name = ['Cardiomegaly','Emphysema','Effusion','Hernia','Nodule','Pneumothorax',
        'Atelectasis','Pleural_Thickening','Mass','Edema','Consolidation','Infiltration','Fibrosis','Pneumonia', 'No Finding']

# %%
os.getcwd()
# Out:
# '/Users/rira/Machine Learning/MLproject1_1'

# %%
for i in name: 
    try:
        if not(os.path.isdir("newFolder/"+ i)):
            os.makedirs(os.path.join("newFolder/"+ i))
    except OSError as e:
        if e.errno != errno.EEXIST:
            print("Failed to create directory!!!!!")
            raise

# %%
# path of X-ray images
path = "../MLproject1_1/data/images 9/"

# Store the image file names in a list as long as they are png
images2 = [f for f in os.listdir(path) if os.path.splitext(f)[-1] == '.png']
images2
# Out:
# ['00019894_004.png',
#  '00018960_022.png',
#  '00019884_010.png',
#  '00019899_027.png',
#  '00019884_004.png',
#  '00019486_001.png',
#  '00018999_000.png',
#  '00020213_056.png',
#  '00020580_002.png',
#  '00018645_000.png',
#  '00018655_000.png',
#  '00019151_000.png',
#  '00020513_026.png',
#  '00020213_081.png',
#  '00018921_005.png',
#  '00020085_014.png',
#  '00018921_011.png',
#  '00020213_095.png',
#  '00020513_032.png',
#  '00019087_040.png',
#  '00020852_002.png',
#  '00019594_007.png',
#  '00019177_002.png',
#  '00018921_039.png',
#  '00019313_004.png',
#  '00019313_010.png',
#  '00020852_016.png',
#  '00019919_014.png',
#  '00019530_018.png',
#  '00020326_080.png',
#  '00020839_001.png',
#  '00018558_003.png',
#  '00020070_004.png',
#  '00020603_006.png',
#  '00020326_043.png',
#  '00020398_003.png',
#  '00020398_017.png',
#  '00019547_001.png',
#  '00018608_001.png',
#  '00019699_004.png',
#  '00020046_006.png',
#  '00019233_008.png',
#  '00019513_003.png',
# ...

# %%
# sorting only image which detected only single disease.
for k in range (len(images2)) : 
    for j in range(len(df["Image Index"])):
        if images2[k] == df["Image Index"][j]:
            a=df["Finding Labels"][j]
            if a in name:
                print(a)
                print(images2[k])
                shutil.move("../MLproject1_1/data/images 9/"+images2[k],"../MLproject1_1/Folder/"+a)
# Out:
# No Finding
# 00018805_001.png
# Infiltration
# 00020213_042.png
# Mass
# 00019369_002.png
# No Finding
# 00019860_005.png
# Mass
# 00018663_002.png
# No Finding
# 00019462_000.png
# No Finding
# 00018989_000.png
# Infiltration
# 00019472_000.png
# No Finding
# 00020249_003.png
# No Finding
# 00018815_001.png
# No Finding
# 00020542_001.png
# No Finding
# 00019860_011.png
# Effusion
# 00019894_010.png
# Pneumothorax
# 00019201_002.png
# No Finding
# 00019065_004.png
# No Finding
# 00019758_004.png
# Pneumonia
# 00019894_038.png
# No Finding
# 00020286_037.png
# No Finding
# 00020307_001.png
# Atelectasis
# 00019237_000.png
# Infiltration
# 00019576_043.png
# Infiltration
# 00018421_006.png
# No Finding
# 00019227_000.png
# Infiltration
# 00019576_057.png
# Effusion
# 00020286_023.png
# No Finding
# 00020095_000.png
# Infiltration
# 00019029_000.png
# No Finding
# 00020874_000.png
# No Finding
# 00020880_001.png
# No Finding
# 00018523_000.png
# Infiltration
# 00020482_004.png
# ...
